# %% [markdown]
# <a href="https://colab.research.google.com/github/CodesbyHim/Data-Structures-in-Python/blob/main/Learning%20Notebooks%20/%20overview_of_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data structure > way of organizing and storing data so that it can be acccessed and manipulated effecinently

# %%
#List >> it is an ordered collection of elements that can be of any data type, integer, float
#List are mutable

# %%
num = [1, 2, 3, 4, 5]

# %%
type(num)
# Out:
# list

# %%
num[0]
# Out:
# 1

# %%
num[1]
# Out:
# 2

# %%
num[4]
# Out:
# 5

# %%
num[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 num[5]
#
# IndexError: list index out of range

# %%
lis = [1, 2, "ajay", True, 3+7j]

# %%
type(lis)
# Out:
# list

# %%
lis
# Out:
# [1, 2, 'ajay', True, (3+7j)]

# %%
lis.append("pwskills")

# %%
lis
# Out:
# [1, 2, 'ajay', True, (3+7j), 'pwskills']

# %%
lis.remove("ajay")

# %%
lis
# Out:
# [1, 2, True, (3+7j), 'pwskills']

# %%
lis[2]
# Out:
# True

# %%
lis = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
type(lis)
# Out:
# list

# %%
lis
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
lis[0][1]
# Out:
# 2

# %%
lis[2][2]
# Out:
# 9

# %%
shopping_list = ["Banana", "Apple", 3, 4.5, True]

# %%
type(shopping_list)
# Out:
# list

# %%
for item in shopping_list:
    print(item, end = " ")
# Out:
# Banana Apple 3 4.5 True

# %%
#Tuples >> immutable

# %%
point = (2, 3)

# %%
point
# Out:
# (2, 3)

# %%
type(point)
# Out:
# tuple

# %%
point = ("Ajay", 1, 2, 2.3)

# %%
point
# Out:
# ('Ajay', 1, 2, 2.3)

# %%
name = ("Ajay", "Sumit", "Bijay")

# %%
name[0]
# Out:
# 'Ajay'

# %%
name[1]
# Out:
# 'Sumit'

# %%
name[1] = "Bangalore"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 name[1] = "Bangalore"
#
# TypeError: 'tuple' object does not support item assignment

# %%
box1  = ("a", "b")
box2 = ("c", "d")

choclate_bag = (box1, box2)

# %%
choclate_bag
# Out:
# (('a', 'b'), ('c', 'd'))

# %%
for bag in choclate_bag:
    for choc in bag:
        print(choc)
# Out:
# a
# b
# c
# d

# %%
#sets>> are unordered collection of unique elements

# %%
s = {"red", "blue"}

# %%
type(s)
# Out:
# set

# %%
s = {"red", "blue", "blue"}

# %%
s
# Out:
# {'blue', 'red'}

# %%
s = {"a", "a", "a", 1.2, 1.2}

# %%
s
# Out:
# {1.2, 'a'}

# %%
s
# Out:
# {1.2, 'a'}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 s[1]
#
# TypeError: 'set' object is not subscriptable

# %%
s.add("pwskills")

# %%
s
# Out:
# {1.2, 'a', 'pwskills'}

# %%
s.add("pwskills")

# %%
s
# Out:
# {1.2, 'a', 'pwskills'}

# %%
s
# Out:
# {1.2, 'a', 'pwskills'}

# %%
s.remove("pwskills")

# %%
s
# Out:
# {1.2, 'a'}

# %%
grocery_list = {"apple", "banana", "orange", "banana", "orange"}
grocery_list
# Out:
# {'apple', 'banana', 'orange'}

# %%
#dictionaries >> key value pair
my_dict = {}

# %%
my_dict
# Out:
# {}

# %%
type(my_dict)
# Out:
# dict

# %%
s = {}
type(s)
# Out:
# dict

# %%
my_dict = {"key_course" : "data science", "duration" : 2}

# %%
type(my_dict)
# Out:
# dict

# %%
phonebook = {"Dad": 1234, "Mom": 234}

# %%
type(phonebook)
# Out:
# dict

# %%
phonebook["Dad"]
# Out:
# 1234

# %%
phonebook = {"Dad": 1234, "Mom": 234, "Dad": 789}

# %%
phonebook
# Out:
# {'Dad': 789, 'Mom': 234}

# %%
phonebook.keys()
# Out:
# dict_keys(['Dad', 'Mom'])

# %%
phonebook.values()
# Out:
# dict_values([789, 234])

# %%
phonebook["Dad"] = "I have changed any no"

# %%
phonebook
# Out:
# {'Dad': 'I have changed any no', 'Mom': 234}

# %%
from array import array # array is similar to list>> homogenous data

# %%
a = array('i', [1, 2, 3, 4])

# %%
type(a)
# Out:
# array.array
